# %% [markdown]
# # Hackathon Notebook

# %%
# Import the usual suspects for data manipulation, statistics, and visualisations.
import pandas as pd # used to "tidy" up and manipulate our data
import numpy as np # used for matrix and numerical calculations; the foundation of pandas
from scipy import stats # contains stats functions and is used to visualise probability distributions
import matplotlib.pyplot as plt # used for visualisations
import seaborn as sns # a more user-friendly library used for visualisations

# %%
#Data Preparation
#Data Preparation
#Data Preparation
#Data Preparation
#Data Preparation
#Data Preparation
#Data Preparation
#Data Preparation

# %%
df = pd.read_csv('data/netflix_titles.csv')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6173
# unique    8807      2                  8807           4528
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             19
# mean       NaN    NaN                   NaN            NaN
# std        NaN    NaN                   NaN            NaN
# min        NaN    NaN                   NaN            NaN
# 25%        NaN    NaN                   NaN            NaN
# 50%        NaN    NaN                   NaN            NaN
# 75%        NaN    NaN                   NaN            NaN
# max        NaN    NaN                   NaN            NaN
#
#                       cast        country       date_added  release_year  \
# count                 7982           7976             8797   8807.000000
# unique                7692            748             1767           NaN
# ...

# %%
# STEP 1: Convert data types
# convert 'date_added' to datetime format
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

# convert 'release_year' to numeric format
df['release_year'] = pd.to_numeric(df['release_year'], errors='coerce')

# %%
#STEP 2: Extract month and year from the 'date_added' column for time-based analysis.
#extract month and year from 'date_added'
df['date_added_month'] = df['date_added'].dt.month
df['date_added_year'] = df['date_added'].dt.year

# %%
duration_null_df = df[df['duration'].isnull()]
duration_null_df
# Out:
#      show_id   type                                 title    director  \
# 5541   s5542  Movie                       Louis C.K. 2017  Louis C.K.
# 5794   s5795  Movie                 Louis C.K.: Hilarious  Louis C.K.
# 5813   s5814  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.
#
#             cast        country date_added  release_year  rating duration  \
# 5541  Louis C.K.  United States 2017-04-04          2017  74 min      NaN
# 5794  Louis C.K.  United States 2016-09-16          2010  84 min      NaN
# 5813  Louis C.K.  United States 2016-08-15          2015  66 min      NaN
#
#      listed_in                                        description  \
# 5541    Movies  Louis C.K. muses on religion, eternal love, gi...
# 5794    Movies  Emmy-winning comedy writer Louis C.K. brings h...
# 5813    Movies  The comic puts his trademark hilarious/thought...
#
#       date_added_month  date_added_year
# 5541               4.0           2017.0
# ...

# %%
# Identify rows with incorrect ratings that should be in the duration column
incorrect_ratings = ['74 min', '84 min', '66 min']
mask = df['rating'].isin(incorrect_ratings) & df['duration'].isnull()

# Move incorrect ratings to the duration column
df.loc[mask, 'duration'] = df['rating']

# Replace these values in the rating column with 'Not Rated' or another appropriate placeholder
df.loc[mask, 'rating'] = 'Not Rated'

# %%
# STEP 3: Handle Missing Values
# Filling missing values in 'director' column with 'Unknown'
df['director'] = df['director'].fillna('Unknown', inplace=False)

# Filling missing values in 'cast' column with 'Unknown'
df['cast'] = df['cast'].fillna('Unknown', inplace=False)

# Filling missing values in 'cast' column with 'Unknown'
df['country'] = df['country'].fillna('Unknown', inplace=False)

# Filling missing values in 'date_added' column with the mode
df['date_added'] = df['date_added'].fillna(df['date_added'].mode()[0], inplace=False)

# Filling missing values in 'date_added_month' column with the mode
df['date_added_month'] = df['date_added_month'].fillna(df['date_added_month'].mode()[0], inplace=False)

# Filling missing values in 'date_added_year' column with the mode
df['date_added_year'] = df['date_added_year'].fillna(df['date_added_year'].mode()[0], inplace=False)

# Filling missing values in 'ratings' column with 'Not rated'
df['rating'] = df['rating'].fillna('Not rated', inplace=False)

# %%
# remove duplicates
df = df.drop_duplicates()

# %%
# STEP 4: Clean Categorical Data
# standardise capitalization in categorical columns
df['type'] = df['type'].str.capitalize()
df['rating'] = df['rating'].str.upper()

# %%
# STEP 5: Remove duplicates
df = df.drop_duplicates()

# %%
#STEP 6: removing outliers
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df_out = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df_out

df = remove_outliers(df, 'release_year')

# %%
# remove any extra spaces from string columns
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x)

# %%
# Creating new columns for duration to seperate movies

df['movie_duration_minutes'] = None

df.loc[df['type'] == 'Movie', 'movie_duration'] = df['duration']
df['movie_duration_minutes'] = df['movie_duration'].str.extract('(\d+)').astype(float)

df.drop(columns=['movie_duration'], inplace=True)

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  Tv show          Blood & Water          Unknown
# 2      s3  Tv show              Ganglands  Julien Leclercq
# 3      s4  Tv show  Jailbirds New Orleans          Unknown
# 4      s5  Tv show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
# Creating new columns for duration to seperate tv shows

df['tv_duration'] = None

df.loc[df['type'] == 'Tv show', 'tv_duration'] = df['duration']
df['tv_duration_seasons'] = df['tv_duration'].str.extract('(\d+)').astype(float)

df.drop(columns=['tv_duration'], inplace=True)

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  Tv show          Blood & Water          Unknown
# 2      s3  Tv show              Ganglands  Julien Leclercq
# 3      s4  Tv show  Jailbirds New Orleans          Unknown
# 4      s5  Tv show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8088 entries, 0 to 8806
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   show_id                 8088 non-null   object
#  1   type                    8088 non-null   object
#  2   title                   8088 non-null   object
#  3   director                8088 non-null   object
#  4   cast                    8088 non-null   object
#  5   country                 8088 non-null   object
#  6   date_added              8088 non-null   datetime64[ns]
#  7   release_year            8088 non-null   int64
#  8   rating                  8088 non-null   object
#  9   duration                8088 non-null   object
#  10  listed_in               8088 non-null   object
#  11  description             8088 non-null   object
#  12  date_added_month        8088 non-null   float64
#  13  date_added_year         8088 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# show_id                      0
# type                         0
# title                        0
# director                     0
# cast                         0
# country                      0
# date_added                   0
# release_year                 0
# rating                       0
# duration                     0
# listed_in                    0
# description                  0
# date_added_month             0
# date_added_year              0
# movie_duration_minutes    2601
# tv_duration_seasons       5487
# dtype: int64

# %%
df.describe(include='all')
# Out:
# /kas/kloud/notebook/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   """Entry point for launching an IPython kernel.
#        show_id   type         title director     cast        country  \
# count     8088   8088          8088     8088     8088           8088
# unique    8088      2          8087     4200     7012            705
# top         s1  Movie  Consequences  Unknown  Unknown  United States
# freq         1   5487             2     2557      806           2494
# first      NaN    NaN           NaN      NaN      NaN            NaN
# last       NaN    NaN           NaN      NaN      NaN            NaN
# mean       NaN    NaN           NaN      NaN      NaN            NaN
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  Tv show          Blood & Water          Unknown
# 2         s3  Tv show              Ganglands  Julien Leclercq
# 3         s4  Tv show  Jailbirds New Orleans          Unknown
# 4         s5  Tv show           Kota Factory          Unknown
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  Tv show            Zombie Dumb          Unknown
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               Unknown  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# Data Exploration
# Data Exploration
# Data Exploration
# Data Exploration
# Data Exploration
# Data Exploration
# Data Exploration
# Data Exploration
# Data Exploration

# %%
#1. Visualize the data using various techniques.

# %%
df['type'].str.split(',').explode().str.strip().value_counts()
# Out:
# Movie      5487
# Tv show    2601
# Name: type, dtype: int64

# %%
# Distribution of Movies and TV Shows
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='type', palette='Set2')
plt.title('Distribution of Movies vs. TV Shows')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# Findings
# This shows us that there are more Movies than TV Shows. Movies are shorter and could be finished within a short time frame, where as TV shows take a while to complete due to new season release at later dates (yearly).

# %%
df['rating'].str.split(',').explode().str.strip().value_counts()
# Out:
# TV-MA        3125
# TV-14        1986
# TV-PG         797
# R             638
# PG-13         379
# TV-Y7         318
# TV-Y          304
# PG            222
# TV-G          207
# NR             73
# G              21
# NOT RATED       7
# TV-Y7-FV        6
# NC-17           3
# UR              2
# Name: rating, dtype: int64

# %%
# Distribution of Ratings
plt.figure(figsize=(12, 8))
sns.countplot(data=df, y='rating', order=df['rating'].value_counts().index, palette='Set3')
plt.title('Distribution of Ratings')
plt.xlabel('Count')
plt.ylabel('Rating')
plt.show()

# Findings
#Shows that TV-MA (mature audience only) ratings are the most common and the least is G rated.
#TV-MA contains content that has strong language and violence and holds a larger audience on Netflix.
#G rating is content meant for general audience, like children and families as it has not bad language, violence, etc. This has a smaller audience within the Netflix customers.

# %%
# Number of Titles Added Over Time
plt.figure(figsize=(14, 8))
df['date_added'] = pd.to_datetime(df['date_added'])
df['year_added'] = df['date_added'].dt.year
df['month_added'] = df['date_added'].dt.month
titles_per_year = df['year_added'].value_counts().sort_index()
titles_per_year.plot(kind='bar', color='skyblue')
plt.title('Number of Titles Added Over Time')
plt.xlabel('Year Added')
plt.ylabel('Number of Titles')
plt.show()

# Findings
# Shows that Netflix has aggresively added more movies and tv shows over the years from 2013-2019. As Netflix grew, they had to add more movies and tv shows to keep customers entertained.
# Shows from 2019-2021, there was a slight decrease due to COVID-19. This caused disruption in producing and release schdeules. Films studios were shut down which caused delays, budgets were also playing a part so they had to control the volume of new content that could be produced.

# %%
#2. Identify any trends or patterns in the data.

# %%
df['country'].str.split(',').explode().str.strip().value_counts()
# Out:
# United States     3266
# India              922
# Unknown            803
# United Kingdom     741
# Canada             425
#                   ...
# Bermuda              1
# Ecuador              1
# Armenia              1
# Mongolia             1
# Montenegro           1
# Name: country, Length: 118, dtype: int64

# %%
# Top 10 Countries by Number of Titles
plt.figure(figsize=(14, 8))
top_countries = df['country'].value_counts().head(10)
sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')
plt.title('Top 10 Countries by Number of Titles')
plt.xlabel('Number of Titles')
plt.ylabel('Country')
plt.show()

# Findings
# Show that US has contirbuted more movies to Netflix that the all the customers of Netflix are interested in as they are a primary market in the movie industry.

# %%
df['listed_in'].str.split(',').explode().str.strip().value_counts()
# Out:
# International Movies            2531
# Dramas                          2147
# Comedies                        1453
# International TV Shows          1334
# Documentaries                    838
# TV Dramas                        754
# Independent Movies               712
# Action & Adventure               671
# Children & Family Movies         585
# TV Comedies                      562
# Romantic Movies                  548
# Thrillers                        533
# Crime TV Shows                   468
# Kids' TV                         428
# Docuseries                       389
# Romantic TV Shows                364
# Music & Musicals                 333
# Stand-Up Comedy                  326
# Horror Movies                    325
# Reality TV                       252
# British TV Shows                 247
# Sci-Fi & Fantasy                 208
# Sports Movies                    203
# Spanish-Language TV Shows        171
# Anime Series                     165
# ...

# %%
# Top Genres
plt.figure(figsize=(14, 8))
top_genres = df['listed_in'].str.split(', ').explode().value_counts().head(10)
sns.barplot(x=top_genres.values, y=top_genres.index, palette='magma')
plt.title('Top 10 Genres')
plt.xlabel('Number of Titles')
plt.ylabel('Genre')
plt.show()

# Findings
# Most movies have international movie genre. This shows that Netlix has a diverse audience.

# %%
# 3. Conduct statistical analysis to explore relationships between variables

# %%
# Relationship between Release Year and Rating
plt.figure(figsize=(14, 8))
sns.boxplot(data=df, x='rating', y='release_year', palette='coolwarm')
plt.title('Relationship between Release Year and Rating')
plt.xlabel('Rating')
plt.ylabel('Release Year')
plt.show()

# Findings
# TV-MA rated shows that it has been more popular recently over the years.
# G rated shows that it was more common and popular in the past years.
# The rest shows there was stead production and popularity of other ratings.

# %%
# Correlation heatmap
plt.figure(figsize=(12, 10))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# Findings
# Shows what columns have strong or weak correlation.
# There's strong correlation between release year and date_added_year/year_added. Weak correlation on the rest.

# %%
# Data analysis
# Data analysis
# Data analysis
# Data analysis
# Data analysis
# Data analysis
# Data analysis
# Data analysis
# Data analysis
# Data analysis

# %%
# 1.Analyse the data to gain insights into user behaviour and preferences.

# The top 3 most common genres are International Movies, Drama and Comedies. 
# This shows that Netflix audience is based around international movies (diverstiy), drama and comedies.
# The top 3 least favourites are TV comedies, Children & Family movies and Action & Adventure.
# This shows that Netflix audience are mostly adults as they have more TV-MA rated (most) movies rather than G rated movies (least).

# Rest of insights gained from visualations are written in the same box as the code.

# %%
# 2. Use Clustering Techniques to Identify Different Groups of Users or Movies:

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Preparing data for clustering for release_year and movie_duration_minutes
df_clustering = df[['release_year', 'movie_duration_minutes']]
df_clustering = df_clustering.dropna()

# Standardize the features
scaler = StandardScaler()
df_clustering_scaled = scaler.fit_transform(df_clustering)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df_clustering['cluster'] = kmeans.fit_predict(df_clustering_scaled)

#Reduce dimensions for visualisations
pca = PCA(n_components=2)
df_clustering_pca = pca.fit_transform(df_clustering_scaled)

df_clustering['pca1'] = df_clustering_pca[:,0]
df_clustering['pca2'] = df_clustering_pca[:,1]

#Plot the clusters
plt.figure(figsize=(14, 8))
sns.scatterplot(data=df_clustering, x='pca1', y='pca2', hue='cluster', palette='viridis')
plt.title('K-Means Clustering of Movies')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# Findings
# Cluster 0: Older movies that have shorter duration
# Cluster 1: Recent movies that have average duration
# Cluster 2: Newest Movies that have longer duration
# Shows us that newer movies are much longer now and netflix may consider releasing more new longer movies.

# %%
# 2. Use Clustering Techniques to Identify Different Groups of Users or Movies:

from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Preparing data for clustering for release_year and tv_duration_seasons
df_clustering = df[['release_year', 'tv_duration_seasons']]
df_clustering = df_clustering.dropna()

# Standardize the features
scaler = StandardScaler()
df_clustering_scaled = scaler.fit_transform(df_clustering)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
df_clustering['cluster'] = kmeans.fit_predict(df_clustering_scaled)

#Reduce dimensions for visualisations
pca = PCA(n_components=2)
df_clustering_pca = pca.fit_transform(df_clustering_scaled)

df_clustering['pca1'] = df_clustering_pca[:,0]
df_clustering['pca2'] = df_clustering_pca[:,1]

#Plot the clusters
plt.figure(figsize=(14, 8))
sns.scatterplot(data=df_clustering, x='pca1', y='pca2', hue='cluster', palette='viridis')
plt.title('K-Means Clustering of TV Shows')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.show()

# Findings
# Cluster 0: Older Tv shows that have fewer seasons
# Cluster 1: Recent Tv shows that have average number of seasons
# Cluster 2: Newest Tv shows that have more seaons 
# Shows us that newer tv shows have more seasons and netflix may consider releasing more new tv shows with more seasons.

# %%
# 3. Test your hypotheses to verify any observations or conclusions.
# Hypthosis 1: Test whether movies and TV Shows have been realeased at different times and what trend in content production of the years

from scipy.stats import ttest_ind

release_year_movie = df[df['type'] == 'Movie']['release_year'].dropna()
release_year_tv_show = df[df['type'] == 'Tv show']['release_year'].dropna()

t_stat_release, p_val_release = ttest_ind(release_year_movie, release_year_tv_show)

print(f"T-statistic for release year: {t_stat_release}")
print(f"P-value for release year: {p_val_release}")


# Interpretation
if p_val_release < 0.05:
    print("Reject the null hypothesis for release year: There is a significant difference in the release years of movies and TV shows.")
else:
    print("Fail to reject the null hypothesis for release year: There is no significant difference in the release years of movies and TV shows.")
# Out:
# T-statistic for release year: -16.481176949248773
# P-value for release year: 4.743071425506036e-60
# Reject the null hypothesis for release year: There is a significant difference in the release years of movies and TV shows.

# %%
# Hypthosis 2: Test the duration of movies and tv shows to under content consumption patterns.

duration_movie = df[df['type'] == 'Movie']['movie_duration_minutes'].dropna()
duration_tv_show = df[df['type'] == 'Tv show']['tv_duration_seasons'].dropna()

t_stat_duration, p_val_duration = ttest_ind(duration_movie, duration_tv_show)

print(f"T-statistic for duration: {t_stat_duration}")
print(f"P-value for duration: {p_val_duration}")

if p_val_duration < 0.05:
    print("Reject the null hypothesis for duration: There is a significant difference in the duration of movies and the number of seasons for TV shows.")
else:
    print("Fail to reject the null hypothesis for duration: There is no significant difference in the duration of movies and the number of seasons for TV shows.")
# Out:
# T-statistic for duration: 181.69108643046653
# P-value for duration: 0.0
# Reject the null hypothesis for duration: There is a significant difference in the duration of movies and the number of seasons for TV shows.
